# %%
import os
from pymfe.mfe import MFE
import pandas as pd
import numpy as np
from fastprogress.fastprogress import master_bar, progress_bar
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## TODO
# - extract meta-features
# - select k best features (k=8,16,32,64,128,all)
# - induce models in meta-features (lightgbm,rf,tabnet) to compare the rmse/mae with deep meta-learning approach

# %%
seed = 42

# %%
path = "../data/"
data = pd.read_csv("../data.csv")
train_df = []
valid_df = []

for index, file in progress_bar(data.iterrows(), total=data.shape[0]):
    df = pd.read_csv(path+file["files"])
    X = df.drop(columns=["class"]).values
    y = df["class"].values
    mfe = MFE(random_state=seed)
    mfe.fit(X, y)
    ft = mfe.extract()
    ft = dict(zip(*ft))
    ft["class"] = file["dt"]
    if file["train"]:
        train_df.append(ft)
    else:
        valid_df.append(ft)
    
train_df = pd.DataFrame(train_df)
valid_df = pd.DataFrame(valid_df)
train_df.to_csv("../mfe.train.csv", index=False)
train_df.to_csv("../mfe.test.csv", index=False)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='393' class='' max='393' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [393/393 12:51<00:00]
#     </div>
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:1566: UserWarning: It is not possible make equal discretization
#   warnings.warn("It is not possible make equal discretization")
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:207: RuntimeWarning: divide by zero encountered in true_divide
#   can_cor_eig_vals = sqr_can_cors / (1 - sqr_can_cors)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'tree_imbalance' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:1566: UserWarning: It is not possible make equal discretization
#   warnings.warn("It is not possible make equal discretization")
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cor' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/scipy/stats/morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: divide by zero encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1271: RuntimeWarning: invalid value encountered in double_scalars
#   (num_inst - num_classes)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'nodes_per_level' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'nodes_repeated' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'tree_imbalance' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:1566: UserWarning: It is not possible make equal discretization
#   warnings.warn("It is not possible make equal discretization")
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cov' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:1566: UserWarning: It is not possible make equal discretization
#   warnings.warn("It is not possible make equal discretization")
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:1566: UserWarning: It is not possible make equal discretization
#   warnings.warn("It is not possible make equal discretization")
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:1566: UserWarning: It is not possible make equal discretization
#   warnings.warn("It is not possible make equal discretization")
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:1566: UserWarning: It is not possible make equal discretization
#   warnings.warn("It is not possible make equal discretization")
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:1566: UserWarning: It is not possible make equal discretization
#   warnings.warn("It is not possible make equal discretization")
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/lib/function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cor' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/scipy/stats/morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: divide by zero encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1271: RuntimeWarning: invalid value encountered in double_scalars
#   (num_inst - num_classes)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:1566: UserWarning: It is not possible make equal discretization
#   warnings.warn("It is not possible make equal discretization")
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# ...
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'cor' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/scipy/stats/morestats.py:1678: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: divide by zero encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1271: RuntimeWarning: invalid value encountered in double_scalars
#   (num_inst - num_classes)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:1566: UserWarning: It is not possible make equal discretization
#   warnings.warn("It is not possible make equal discretization")
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: divide by zero encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: divide by zero encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1271: RuntimeWarning: invalid value encountered in double_scalars
#   (num_inst - num_classes)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'can_cor' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'g_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:606: RuntimeWarning: Can't extract feature 'h_mean'.
#  Exception message: ValueError('Harmonic mean only defined if all elements greater than or equal to zero').
#  Will set it as 'np.nan' for all summary functions.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'sd'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/_internal.py:731: RuntimeWarning: Can't summarize feature 'h_mean' with summary 'mean'. Will set it as 'np.nan'.
#   warnings.warn(
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1267: RuntimeWarning: invalid value encountered in log
#   np.log(np.linalg.det(S_i)) for S_i in sample_cov_matrices
# /home/jader/Projects/deep-meta-learning/venv/lib/python3.8/site-packages/pymfe/statistical.py:1272: RuntimeWarning: invalid value encountered in log
#   * np.log(np.linalg.det(pooled_cov_mat))

# %%
xtrain = train_df.drop(columns=["class"]).values
ytrain = train_df["class"].values
xtest = valid_df.drop(columns=["class"]).values
ytest = valid_df["class"].values
lg = LGBMRegressor(random_state=seed, objective='l1')

# %%
lg.fit(xtrain, ytrain)
# Out:
# LGBMRegressor(objective='mae', random_state=42)

# %%
mean_absolute_error(ytest, lg.predict(xtest))
# Out:
# 4.027039344274807

# %%
(ytest[:3], lg.predict(xtest)[:3])
# Out:
# (array([59.14942529, 81.375     , 86.82971014]),
#  array([61.0188391 , 81.21646566, 87.80987857]))
